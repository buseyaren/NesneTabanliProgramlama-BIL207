# %% [markdown]
# ## Miras, Kalıtım - Inheritance
#
#  Biz, programlama yaparken birden fazla class kullanabiliriz. Yazmış olduğumuz bir class‘a ait özellikleri başka bir class‘ta kullanmak istediğimizde bu özellikleri kalıtım yoluyla almaktayız. Bu işleme miras almak da denilmektedir. Tıpkı bir çocuğun annesine ya da babasına ait birkaç özelliği alması gibi class‘lar da özelliklerini birbirlerinden inheritance yoluyla alabilir.
#
#  Child ve parent olmak üzere 2 farklı class yapısını kullanır.
#
# * Ebeveyn sınıf; değişkenlerini ve fonksiyonlarını kalıtım ile kullandırır. (parent)
# * Çocuk sınıf; ebeveyn sınıftan kalıtım ile değişken ve methodaları alarak kullanabilir. (child) - Ebeveynden türetilmiş

# %% [markdown]
# ![python-inheritance.jpg](attachment:python-inheritance.jpg)

# %% [markdown]
# ![class-inheritance.png](attachment:class-inheritance.png)

# %% [markdown]
# Bir sınıfta bulunan aynı kodları tekrar tekrar yazmak yerine ilgili sınıfın aynı kodlarını kullanacak alt sınıflar oluşturulabilir.
#
# Miras almada ebeveyn (parent) ve çocuk (child) olmak üzere iki sınıf yapısından bahsedilir. Child class yapısı parent class yapısının niteliklerini veya metotlarını kullanabilen ve dolayısıyla parent class yapısından türetilmesinden ötürü sub class (alt sınıf) olarak da bilinmektedir.
#
# Sınıfları anlattığımız dersimizde initializier (başlatıcı) kelimesinden türetilen __init__ () fonksiyonunun temel yapıcı fonksiyonu olduğundan bahsetmiştik. __init__ () fonksiyonu bir nesne yazıldığında öncelikli olarak çalıştırılırlar.

# %% [markdown]
# Hayvan Sınıfı Örneği

# %% [markdown]
# ![Ekran%20Resmi%202022-12-12%2023.25.40.png](attachment:Ekran%20Resmi%202022-12-12%2023.25.40.png)

# %%
#parent class - super class
class Animal: #super class
    "constructor - yapıcı, inşa edici method"
    def __init__(self):
        print("Animal is created..")
    def toString(self):
        print("Animal")
    def walk(self):
        print("Animal is walk")
    def run(self):
        print("Animal is run")
        
#child class -derived (türetilmiş) class
class Monkey(Animal): #super class - Animal sınıfının çocuğu
    def __init__(self):
        #super().__init__() #use init of parent - Parent classının initialize içeriğini childa aktarıyor
         #Animal is created..
        #print("Monkey is created..")
        
    def toString(self):
        print("Monkey")
        
    def climb(self):
        print("Monkey can climb")
        
monkey1 = Monkey()
# Out:
# Animal is created..

# %%
class Vehicle:
    "constructor"
    def __init__(self):
        print("Vehicle is created")
    def fuelAmount(self):
        print("Fuel amount method is created")
    def capacity(self):
        print("Capacity method is created")
    def applyBrakes(self):
        print("Apply brake method is created")
class Bus(Vehicle):
    def __init__(self):
        #super().__init__()
        print("Bus is created")
class Car(Vehicle):
    def __init__(self):
        print("Car is created") 
class Truck(Vehicle):
    def __init__(self):
        print("Truck is created")  
b1 = Bus()
# Out:
# Bus is created

# %%
monkey1.toString()

# %%
monkey1.walk()

# %%
monkey1.climb()

# %%
class Bird(Animal):
    def __init__(self):
        super().__init__
        print("Bird is created..")
    
    def fly(self):
        print("Bird can fly")

# %%
bird1 = Bird()

# %%
bird1.climb()

# %%
bird1.toString()

# %%
bird1.walk()

# %%
bird1.climb()

# %% [markdown]
# ![soru.png](attachment:soru.png)

# %%
class A:
     def __init__(self, i = 100):
        #self.i = i
        print("i",i)
class B(A):
     def __init__(self, j = 10):
        self.j = j
b = B()
b.i
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/fk/qk052_7906q3mq6qp87ncg900000gn/T/ipykernel_2407/1479085468.py in <module>
#       7         self.j = j
#       8 b = B()
# ----> 9 b.i
#
# AttributeError: 'B' object has no attribute 'i'

# %% [markdown]
# ## Inheritance Project

# %% [markdown]
# ![proje.png](attachment:proje.png)

# %%
class Website:
    "parent class"
    def __init__(self, name, surname):
        self.name = name
        self.surname = surname
        
    def loginInfo(self):
        print(self.name + " " + self.surname)

# %%
p1 = Website("Buse Yaren", "Tekin")

# %%
p1.loginInfo()

# %% [markdown]
# Web sitelerine giriş yapılırken bazı durumlarda farklı değişkenler ile giriş yapılmak istenebilir;

# %%
class Website:
    "parent class"
    def __init__(self, name, surname):
        self.name = name
        self.surname = surname
        
    def loginInfo(self):
        print(self.name + " " + self.surname)
        
class Website1(Website):
    "child class"
    def __init__(self, name, surname, ids):
        super().__init__() #parent classın initini çağırır.
        self.ids = ids
    def login(self): #parent classında name ve surname initialize edilir.
        print(self.name + " "+ self.surname + " " +self.ids)
p2 = Website1("Buse Yaren", "Tekin", "37")

# %%
class Website:
    "parent class"
    def __init__(self, name, surname):
        self.name = name
        self.surname = surname
        
    def loginInfo(self):
        print(self.name + " " + self.surname)
        
class Website1(Website):
    "child class"
    def __init__(self, name, surname, ids):
        super().__init__(name, surname) #parent classın initini çağırır.
        self.ids = ids
    def login(self): #parent classında name ve surname initialize edilir.
        print(self.name + " "+ self.surname + " " +self.ids)
p2 = Website1("Buse Yaren", "Tekin", "37")

# %%
p2.ids

# %%
p2.login()

# %%
p2.loginInfo()

# %% [markdown]
# ## Assignment - Ödev 2
#
# Website2 adında bir sınıf oluşturarak initializer metodunda name, surname ve email parametreleri alarak kendi içerisinde email'i initalize ettikten sonra o sınıfa ait bir login sınıfı oluştur.
# Deadline: 28 Aralık 2022

# %%
class Person:
    def __init__(self, fname, lname):
        self.firstname = fname
        self.lastname = lname

    def printname(self):
        print(self.firstname, self.lastname)

#Use the Person class to create an object, and then execute the printname method:

x = Person("John", "Doe")
x.printname()

# %% [markdown]
# ## Child Class Oluşturma

# %%
class Student(Person):
    pass

# %%
s = Student("Mike", "Olsen")
s.printname()

# %% [markdown]
# ## __init__( ) işlevini ekleyin
# Şimdiye kadar, ebeveyninden özellikleri ve yöntemleri miras alan bir alt sınıf yarattık.
#
# Alt sınıfa (pass anahtar sözcüğü yerine) __init__() işlevini eklemek istiyoruz.

# %%
class Student(Person):
    def __init__(self, fname, lname):
    #add properties etc.
        pass

# %% [markdown]
# __init__() işlevini eklediğinizde, alt sınıf artık ebeveynin __init__() işlevini devralmaz.
#
# **Not: Çocuğun __init__() işlevi, ebeveynin __init__() işlevinin mirasını geçersiz kılar.** (OVERRIDE)
#
# ## Override
#
# Nesne yönelimli programlamada yöntem geçersiz kılma, bir alt sınıfın veya alt sınıfın, üst sınıflarından veya üst sınıflarından biri tarafından zaten sağlanan bir yöntemin belirli bir uygulamasını sağlamasına izin veren bir dil özelliğidir.
#
# Nesne Yönelimli (Object Oriented) Programlama'da, ana sınıftaki bazı metodlara, o sınıftan türetilen yeni sınıflarda ihtiyaç duyulmayabilir ya da bu metodlar üzerinde değişiklikler yapılması gerekebilir. Bu durum genellikle yazılan kodun, bir temel sınıf ve bu sınıftan türetilmiş farklı sınıfları etkileyeceği zamanlarda ortaya çıkar ve Overriding (geçersiz kılma) kullanılarak çözülebilir.

# %% [markdown]
# ![440px-Method_overriding_in_subclass.svg.png](attachment:440px-Method_overriding_in_subclass.svg.png)
#
#
# Overriding bir sınıfa ait bir metodun, o sınıftan türetilmiş bir sınıf içerisinde aynı isimli bir metod tanımlanarak, bu metodun temel sınıftaki metodun yerine geçirmeye denir. Bu işlem,bir metodun  aynı sınıftan türetilmiş  farklı sınıflarda farklı işlere yaramasını sağlar. Türetilmiş sınıfatki metodun adından önce override anahtar sözcüğü eklenerek temel sınıftaki metod geçersiz kılınır.

# %% [markdown]
# ![overriding-in-java.png](attachment:overriding-in-java.png)

# %%
class Student(Person1):
    def __init__(self, fname, lname):
        Person1.__init__(self, fname, lname)
p3 = Person1("Hanifi", "Ozcan")

# %% [markdown]
# ## super(  ) İşlevini kullanın
# Python ayrıca, alt sınıfın ebeveyninden tüm yöntemleri ve özellikleri devralmasını sağlayacak bir super() işlevine sahiptir:

# %%
class Student(Person):
    def __init__(self, fname, lname):
        super().__init__(fname, lname)
p3 = Student("Hanifi", "Ozcan")

# %% [markdown]
# super() işlevini kullanarak, üst öğenin adını kullanmanız gerekmez, üst öğeden yöntemleri ve özellikleri otomatik olarak devralır.

# %%
class Student(Person):
    def __init__(self, fname, lname, year):
        super().__init__(fname, lname,year)
        self.graduationyear = year
p_new = Student("Mike", "Olsen", 2019)

# %%
class Student(Person):
    def __init__(self, fname, lname, year):
        super().__init__(fname, lname)
        self.graduationyear = year
p_new.firstname

# %% [markdown]
# **Short Assignment:** Student sınıfına hoş geldiniz adlı bir yöntem ekleyin:

# %%
class Student(Person):
    def __init__(self, fname, lname, year):
        super().__init__(fname, lname)
        self.graduationyear = year

    def welcome(self):
        print("Welcome", self.firstname, self.lastname, "to the class of", self.graduationyear)

# %%
s1 = Student("Mike", "Olsen", 2019)
s1.welcome()

# %% [markdown]
# ## Soru
#
# x adında bir nesne yaratmak için Student sınıfını kullandık.
#
# x nesnesinin printname yöntemini yürütmek için doğru sözdizimi nedir?
#
# ![Ekran%20Resmi%202022-12-26%2021.35.25.png](attachment:Ekran%20Resmi%202022-12-26%2021.35.25.png)

# %% [markdown]
# ## Örnek
#
# Ref: https://python-istihza.yazbel.com/nesne_tabanli_programlama5.html

# %%
class Oyuncu():
    def __init__(self, isim, rütbe):
        self.isim = isim
        self.rütbe = rütbe
        self.güç = 0

    def hareket_et(self):
        print('hareket ediliyor...')

    def puan_kazan(self):
        print('puan kazanıldı')

    def puan_kaybet(self):
        print('puan kaybedildi')

class Asker(Oyuncu):
    pass

# %%
o1 = Oyuncu("Hanifi", "Subay")
o1.puan_kazan()

# %%
class Oyuncu():
    def __init__(self, isim, rütbe):
        self.isim = isim
        self.rütbe = rütbe
        self.güç = 0

    def hareket_et(self):
        print('hareket ediliyor...')

    def puan_kazan(self):
        print('puan kazanıldı')

    def puan_kaybet(self):
        print('puan kaybedildi')

"Bu taban sınıf, kendisinden türeyecek alt sınıfların ortak nitelik ve metotlarını tanımlar."
" Şu sınıflar ise, yukarıdaki taban sınıftan türeyen birer alt sınıftır:"
class Asker(Oyuncu):
    pass

class İşçi(Oyuncu):
    pass

class Yönetici(Oyuncu):
    pass

# %%
asker1 = Asker('Ahmet', 'İstihkamcı')

# %%
işçi1 = İşçi('Mehmet', 'Usta')

# %%
yönetici1 = Yönetici('Selim', 'Müdür')

# %%
asker1.hareket_et()

# %%
işçi1.puan_kaybet()

# %%
işçi1.güç

# %% [markdown]
# Artık bir taban sınıfa ait metodu alt sınıfa miras yoluyla aktarırken nasıl yeniden tanımlayacağımızı öğrendik. Ayrıca alt sınıflara nasıl yeni metot ve nitelik ekleyeceğimizi de biliyoruz. Ama mesela, self.isim ve self.rütbe değişkenlerini korurken, taban sınıf içinde 0 değeri ile gösterilen self.güç değişkenini Asker(), İşçi() ve Yönetici() sınıflarının her biri içinde nasıl farklı bir değerle göstereceğimizi bilmiyoruz. Yani self.güç değerini Asker() sınıfı içinde 100, İşçi() sınıfı içinde 70, Yönetici() sınıfı içinde ise 50 ile göstermek istesek nasıl bir yol takip etmemiz gerektiği konusunda bir fikrimiz yok. İsterseniz şu ana kadar bildiğimiz yöntemleri kullanarak bu amacımızı gerçekleştirmeyi bir deneyelim:
#
# ![Ekran%20Resmi%202022-12-26%2021.38.05.png](attachment:Ekran%20Resmi%202022-12-26%2021.38.05.png)

# %%
class Oyuncu():
    def __init__(self, isim, rütbe):
        self.isim = isim
        self.rütbe = rütbe
        self.güç = 0

    def hareket_et(self):
        print('hareket ediliyor...')

    def puan_kazan(self):
        print('puan kazanıldı')

    def puan_kaybet(self):
        print('puan kaybedildi')

class Asker(Oyuncu): #override
    def __init__(self, isim, rütbe):
        self.güç = 100

class İşçi(Oyuncu): #override
    def __init__(self, isim, rütbe):
        self.güç = 70

class Yönetici(Oyuncu): #override
    def __init__(self, isim, rütbe):
        self.güç = 50

# %%
asker2 = Asker('Yılmaz', 'Subay')

# %%
asker2.güç

# %% [markdown]
# Burada taban sınıfın __init__() metodunu alt sınıflarda yeniden tanımladık. Bu kodları bu şekilde yazıp çalıştırdığımızda self.güç değerinin her bir alt sınıf için istediğimiz değere sahip olduğunu görürüz. Ancak burada şöyle bir sorun var. Bu kodları bu şekilde yazarak self.isim ve self.rütbe değişkenlerinin değerini maalesef kaybettik!
#
# __init__() metodunun parametre listesine isim ve rütbe parametrelerini yazdığımız halde bunları kodlarımız içinde herhangi bir şekilde kullanmadığımız için, bu parametrelerin listede görünüyor olması bir şey ifade etmiyor. Yani alt sınıflarda tanımladığımız __init__() metodu bizden isim ve rütbe adlı iki parametre bekliyor olsa da, bu parametrelerin değerini kodlar içinde kullanmadığımız için bu parametrelere değer atamamız herhangi bir amaca hizmet etmiyor.

# %%
class Asker(Oyuncu):
    def __init__(self, isim, rütbe):
        self.isim = isim
        self.rütbe = rütbe
        self.güç = 100

class İşçi(Oyuncu):
    def __init__(self, isim, rütbe):
        self.isim = isim
        self.rütbe = rütbe
        self.güç = 70

class Yönetici(Oyuncu):
    def __init__(self, isim, rütbe):
        self.isim = isim
        self.rütbe = rütbe
        self.güç = 50

# %%
asker2 = Asker('Yılmaz', 'Subay')
asker2.isim
